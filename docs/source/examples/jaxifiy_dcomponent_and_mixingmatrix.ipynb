# %% [markdown]
# # SED evaluation

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from ctypes import util
from scipy import constants
import pylab as pl
import numpy as np
from matplotlib import rcParams, cm
rcParams['figure.figsize'] = 12, 8

import jax
from jax import numpy as jnp
from jax import jit, grad, vmap
# Imports needed for component separation
from fgbuster import CMB, Dust, Synchrotron, AnalyticComponent, MixingMatrix
import fgbuster.utils as fgbuster_utils

# %% [markdown]
# ## `AnalyticComponenet`
# The `component_model` module collects classes for SED evaluation. It has mainly two classes:
#
# * `Component`, abstract class which defines the shared API
#
#     - Evaluation of the SED as well as its first and second order derivatives with respect to the free parameters
#     - Keep track of the free parameters
#
# * `AnalyticComponent`
#
#     - Construct a `Component` from an analytic expression
#
# We'll now focus on the latter.
# An `AnalyticComponent` can be constructed from anything that can be parsed by `sympy`, which include all the most common mathematical functions. A variable called `nu` has to be used to expresses the frequency dependence.

# %% [markdown]
# ### Construction
# As an example, consider the SED of a modified back body

# %%
analytic_expr = ('(nu / nu0)**(1 + beta_d) *'
                 '(exp(nu0 / temp * h_over_k) -1)'
                 '/ (exp(nu / temp * h_over_k) - 1)'
                 )

# %%
comp = AnalyticComponent(analytic_expr)

# %% [markdown]
# The free parameters are automatically detected

# %%
comp.params
# Out:
# ['beta_d', 'h_over_k', 'nu0', 'temp']

# %% [markdown]
# As in this case, some of them are not really free but we did not want to clutter the expression by hardcoding the value. Their value can be specified at construction time.

# %%
h_over_k_val = constants.h * 1e9 / constants.k  # Assumes frequencies in GHz
nu0_val = 353.

comp = AnalyticComponent(analytic_expr,  # Same as before
                         h_over_k=h_over_k_val, nu0=nu0_val)  # but now keyword arguments fix some variables

# %% [markdown]
# and they are no longer free parameters

# %%
comp.params
# Out:
# ['beta_d', 'temp']

# %% [markdown]
# ### Evaluation
# Efficient evaluators of the analytic expression are created at construction time. The expression can be evaluated both for a single value and for an array of values. (Note that the free parameters are passed in the same order they appear in `comp.params`)

# %%
nu_scalar = jnp.array(50)
beta_scalar = jnp.array(1.6)
temp_scalar = jnp.array(16.)

comp.eval(nu_scalar, beta_scalar, temp_scalar)
jitted_eval = jax.jit(comp.eval)
jitted_eval(nu_scalar, beta_scalar, temp_scalar)
# Out:
# Array([0.07227074], dtype=float32, weak_type=True)

# %%
nu_vector = jnp.logspace(1, 3, 20)

# %time sed =jitted_eval(nu_vector, beta_scalar, temp_scalar)

print('Output shape is :', sed.shape)
# Out:
# CPU times: user 32.6 ms, sys: 1.07 ms, total: 33.7 ms
# Wall time: 65 ms
# Output shape is : (20,)

# %%
_ = pl.loglog(nu_vector, sed)

# %% [markdown]
# Also the free parameters can be arrays

# %%
beta_vector = jnp.linspace(1.2, 2.2, 4)
temp_vector = jnp.linspace(15, 27, 4)

seds = jitted_eval(nu_vector, beta_vector, temp_vector)

print('Output shape is :', seds.shape)
# Out:
# Output shape is : (4, 20)

# %%
colors_map = cm.ScalarMappable()
colors_map.set_array(beta_vector)
colors_map.autoscale()
colors = lambda x: colors_map.to_rgba(x)
for sed, beta, temp in zip(seds, beta_vector, temp_vector):
    pl.loglog(nu_vector, sed, c=colors(beta), label='Temp: %.0f   Beta: %.1f' % (temp, beta))
_ = pl.legend()

# %% [markdown]
# They can be anything that is bradcating-compatible

# %%
sedss = comp.eval(nu_vector,beta_vector, temp_vector)

print('Output shape is :', sedss.shape)

nu_vector_d, beta_vector_d , temp_vector_d =  fgbuster_utils.make_broadcastable(nu_vector,beta_vector, temp_vector[:, np.newaxis])
sedss = comp.eval(nu_vector_d, beta_vector_d , temp_vector_d)

print('Output shape is :', sedss.shape)
# Out:
# Output shape is : (4, 20)
# Output shape is : (4, 4, 20)

# %%
linewidths = lambda x: (x - temp_vector.min()) / 4. + 1

# Legend kludge
for temp in temp_vector:
    pl.plot([353.]*2, [1, 1.001], c='k', lw=linewidths(temp),
              label='Temp: %.0f' % temp)
for beta in beta_vector:
    pl.plot([353.]*2, [1, 1.001], c=colors(beta), lw=2,
              label='Beta: %.1f' % beta)
# Plotting
for temp, seds in zip(temp_vector, sedss):
    for beta, sed in zip(beta_vector, seds):
        pl.loglog(nu_vector, sed,
                  c=colors(beta), lw=linewidths(temp))

_ = pl.legend()

# %% [markdown]
# Evaluation is reasonably quick. For example, evaluating a pixel-dependent SED over 5 frequency bands at `nside=1024` takes few seconds.

# %%
nu_vector_d , beta_vector_d, temp_vector_d = fgbuster_utils.make_broadcastable(nu_vector[::4], jnp.linspace(1., 2., 12*1024**2), jnp.array(20.))
comp.eval(nu_vector_d , beta_vector_d, temp_vector_d).shape
# Out:
# (12582912, 5)

# %% [markdown]
# ### Derivatives
# Another important feature of the `AnalyticComponent`s is that the derivatives with respect to the parameters are computed analytically at construction time and evaluate with respect to all the parameters using

# %%
beta_scaler = jnp.array(1.6)
temp_scaler = jnp.array(20.)

diffs = comp.diff(nu_vector, beta_scaler, temp_scaler)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 diffs = comp.diff(nu_vector, 1.6, 20.)
#
# File ~/Project/fgbuster/fgbuster/component_model.py:166, in Component.diff(self, nu, *params)
#     128 """ Evaluate the derivative of the SED
#     129
#     130 Parameters
#    (...)
#     144     evaluated derivative
#     145 """
#     146 # assert len(params) == self.n_param
#     147 # if not params:
#     148 #     return []
#    (...)
#     163 # return res
#     164 # self._lambda_diff(nu, *params)
# --> 166 return jacrev(self.eval,argnums=tuple(range(1,len(params))))(nu,*params)
#
# File ~/micromamba/envs/fg/lib/python3.10/site-packages/jax/_src/api.py:941, in jacrev.<locals>.jacfun(*args, **kwargs)
#     939 tree_map(partial(_check_input_dtype_jacrev, holomorphic, allow_int), dyn_args)
#     940 if not has_aux:
# --> 941   y, pullback = _vjp(f_partial, *dyn_args)
#     942 else:
#     943   y, pullback, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/micromamba/envs/fg/lib/python3.10/site-packages/jax/_src/api.py:2223, in _vjp(fun, has_aux, reduce_axes, *primals)
#    2221 if not has_aux:
#    2222   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2223   out_primal, out_vjp = ad.vjp(
#    2224       flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2225   out_tree = out_tree()
#    2226 else:
#
# File ~/micromamba/envs/fg/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:142, in vjp(traceable, primals, has_aux, reduce_axes)
#     140 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     141   if not has_aux:
# --> 142     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     143   else:
#     144     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/micromamba/envs/fg/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:131, in linearize(traceable, *primals, **kwargs)
#     129 _, in_tree = tree_flatten(((primals, primals), {}))
#     130 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 131 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     132 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     133 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/micromamba/envs/fg/lib/python3.10/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/micromamba/envs/fg/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:774, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775   assert not env
#     776   del main, fun, env
#
# File ~/micromamba/envs/fg/lib/python3.10/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# File ~/Project/fgbuster/fgbuster/utils/utils.py:55, in broadcasted.<locals>.wrapper(comp, *args, **kwargs)
#      54 def wrapper(comp,*args, **kwargs):
# ---> 55     broadcastable_args = make_broadcastable_ndim(*args)
#      56     return f(comp,*broadcastable_args, **kwargs)
#
# File ~/Project/fgbuster/fgbuster/utils/utils.py:79, in make_broadcastable_ndim(*args)
#      77 def make_broadcastable_ndim(*args):
#      78     # Step 1: Inspect dimensions and prepare mapping
# ---> 79     chex.assert_tree_has_only_ndarrays(args)
#      81     dims_map = {}
#      82     reverse_dims_map = defaultdict(list)
#
# File ~/micromamba/envs/fg/lib/python3.10/site-packages/chex/_src/asserts_internal.py:278, in chex_assertion.<locals>._chex_assert_fn(custom_message, custom_message_format_vars, include_default_message, exception_type, *args, **kwargs)
#     276 else:
#     277   try:
# --> 278     host_assertion_fn(
#     279         *args,
#     280         custom_message=custom_message,
#     281         custom_message_format_vars=custom_message_format_vars,
#     282         include_default_message=include_default_message,
#     283         exception_type=exception_type,
#     284         **kwargs)
#     285   except jax.errors.ConcretizationTypeError as exc:
#     286     msg = ("Chex assertion detected `ConcretizationTypeError`: it is very "
#     287            "likely that it tried to access tensors' values during tracing. "
#     288            "Make sure that you defined a jittable version of this chex "
#     289            "assertion; if that does not help, please file a bug.")
#
# File ~/micromamba/envs/fg/lib/python3.10/site-packages/chex/_src/asserts_internal.py:196, in _make_host_assertion.<locals>._assert_on_host(custom_message, custom_message_format_vars, include_default_message, exception_type, *args, **kwargs)
#     193     custom_message = custom_message.format(*custom_message_format_vars)
#     194   error_msg = f"{error_msg} [{custom_message}]"
# --> 196 raise exception_type(error_msg)
#
# AssertionError: [Chex] Assertion assert_tree_has_only_ndarrays failed: Tree leaf '2' is not an ndarray (type=<class 'float'>).

# %%
for diff, param in zip(diffs, comp.params):
    pl.semilogx(nu_vector, diff, label=param)
_ = pl.legend()

# %% [markdown]
# ### Predefined Components
# Popular analytic SEDs are ready to be used. For example, we construct the very same `Component` we have been using above with

# %%
dust = Dust(353., units='K_RJ')
print(dust.params)

# %%
np.allclose(comp.eval(nu_vector, beta_vector, temp_vector), 
            dust.eval(nu_vector, beta_vector, temp_vector)
           )

# %% [markdown]
# As for the components, parameters can be fixed at construction time

# %%
dust_fixed_temp = Dust(353., temp=temp_scalar, units='K_RJ')
print(dust_fixed_temp.params)

# %%
np.allclose(comp.eval(nu_vector, beta_vector, temp_scalar), 
            dust_fixed_temp.eval(nu_vector, beta_vector)
           )

# %% [markdown]
# ## Mixing Matrix
# The mixing matrix allows to collect components and evaluate them

# %%
mixing_matrix = MixingMatrix(Dust(353.), CMB(), Synchrotron(70.))

# %%
mixing_matrix.params

# %%
mixing_matrix.components

# %% [markdown]
# As the `Component`s, the SED and its derivative can be easily evaluated

# %%
mm_val = mixing_matrix.eval(nu_vector, 1.6, 20., -3)

print('Output shape is :', mm_val.shape)

# %%
for sed, name in zip(mm_val.T, mixing_matrix.components):
    pl.loglog(nu_vector, sed, label=name)
_ = pl.legend()

# %%
mm_diffs = mixing_matrix.diff(nu_vector, 1.6, 20., -1)

# %%
for mm_diff, param in zip(mm_diffs, mixing_matrix.params):
    plot = pl.loglog(nu_vector, mm_diff, label=param)
    pl.loglog(nu_vector, -mm_diff, ls='--', c=plot[-1].get_color())
_ = pl.legend()

# %% [markdown]
# Note that only the column affected by the derivative is reported in the output.

# %%
mm_diffs[0].shape

# %% [markdown]
# For each parameter, the index of the column affected can be retrieved from the `comp_of_dB` attribute.

# %%
mixing_matrix.comp_of_dB
